# %% [markdown]
# ![p1.jpg](attachment:e9845baf-3d92-4a8f-b337-a9b910126f08.jpg)

# %% [markdown]
# ![p2.jpg](attachment:abb02b9e-2557-4c29-aab9-11f0be91bec6.jpg)

# %% [markdown]
# ![p3.jpg](attachment:d52ce22a-a597-4250-8c00-f7ad5e41d970.jpg)
